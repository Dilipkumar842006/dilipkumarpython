# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",10)
print("original data \n")
df=pd.read_excel("performance example.xlsx")
print(df)
# Out:
# original data
#
#     s.no  roll.no          name  eng  tamil  maths  science  social science  \
# 0      1        1        dragon   34   45.0   35.0     63.0            86.0
# 1      2        2        ramesh   35    4.0    NaN      NaN            56.0
# 2      3        3         kumar   53    5.0   78.0      NaN            97.0
# 3      4        4        sankar   67    3.0   45.0     36.0            87.0
# 4      5        5          babu   58   24.0   79.0     36.0            46.0
# 5      6        6    snake babu   24    NaN  356.0     79.0            68.0
# 6      7        7   kokki kumar   45   64.0    NaN     86.0            56.0
# 7      8        8     venkatesh   68   17.0    NaN     87.0             NaN
# 8      9        9        rakesh    2   99.0   46.0     36.0            56.0
# 9     10       10         funny   46    4.0   23.0     36.0            97.0
# 10    11       11         vijay   23    8.0   56.0     79.0            87.0
# ...

# %%
f=df["name"].str.strip()
f.to_excel("/Users/student/Downloads/performance1 eg.xlsx")

# %%
print("\n Replace Value:")
k=df.fillna(method="pad")
print(k)
print("\n Updated list \n")
k.to_excel("/Users/student/Downloads/performance1 eg.xlsx")
# Out:
#  Replace Value:
#     s.no  roll.no          name  eng  tamil  maths  science  social science  \
# 0      1        1        dragon   34   45.0   35.0     63.0            86.0
# 1      2        2        ramesh   35    4.0   35.0     63.0            56.0
# 2      3        3         kumar   53    5.0   78.0     63.0            97.0
# 3      4        4        sankar   67    3.0   45.0     36.0            87.0
# 4      5        5          babu   58   24.0   79.0     36.0            46.0
# 5      6        6    snake babu   24   24.0  356.0     79.0            68.0
# 6      7        7   kokki kumar   45   64.0  356.0     86.0            56.0
# 7      8        8     venkatesh   68   17.0  356.0     87.0            56.0
# 8      9        9        rakesh    2   99.0   46.0     36.0            56.0
# 9     10       10         funny   46    4.0   23.0     36.0            97.0
# 10    11       11         vijay   23    8.0   56.0     79.0            87.0
# ...

# %%
print("\n Replace Value:")
k=df.fillna(method="pad")
print(k)
print("\n upadted list /n")
k.to_excel("/Users/student/Downloads/performance1 eg.xlsx")
# Out:
#  Replace Value:
#     s.no  roll.no          name  eng  tamil  maths  science  social science  \
# 0      1        1        dragon   34   45.0   35.0     63.0            86.0
# 1      2        2        ramesh   35    4.0   35.0     63.0            56.0
# 2      3        3         kumar   53    5.0   78.0     63.0            97.0
# 3      4        4        sankar   67    3.0   45.0     36.0            87.0
# 4      5        5          babu   58   24.0   79.0     36.0            46.0
# 5      6        6    snake babu   24   24.0  356.0     79.0            68.0
# 6      7        7   kokki kumar   45   64.0  356.0     86.0            56.0
# 7      8        8     venkatesh   68   17.0  356.0     87.0            56.0
# 8      9        9        rakesh    2   99.0   46.0     36.0            56.0
# 9     10       10         funny   46    4.0   23.0     36.0            97.0
# 10    11       11         vijay   23    8.0   56.0     79.0            87.0
# ...

# %%
print("\n Drop one particular column and its values: \n")
k.drop(["maths"],axis=1,inplace=True)
print(k)
print("\n updated list \n")
k.to_excel("/Users/student/Downloads/performance1 eg.xlsx")
# Out:
#  Drop one particular column and its values:
#
#     s.no  roll.no          name  eng  tamil  science  total marks
# 0      1        1        dragon   34   45.0     63.0          263
# 1      2        2        ramesh   35    4.0     63.0           95
# 2      3        3         kumar   53    5.0     63.0          233
# 3      4        4        sankar   67    3.0     36.0          238
# 4      5        5          babu   58   24.0     36.0          243
# 5      6        6    snake babu   24   24.0     79.0          527
# 6      7        7   kokki kumar   45   64.0     86.0          251
# 7      8        8     venkatesh   68   17.0     87.0          172
# 8      9        9        rakesh    2   99.0     36.0          239
# 9     10       10         funny   46    4.0     36.0          206
# 10    11       11         vijay   23    8.0     79.0          253
# 11    12       12  thandaiyaar    56   96.0     86.0          381
# 12    13       13        pettai   97   29.0     87.0          368
# ...
